# %%
# -*- coding: utf-8 -*-
"""
Created on Fri Sep 18 07:37:58 2020

@author: hwicaksono
"""


import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelBinarizer

import plotly.express as px

# %% [markdown]
# # Load customer dataset

# %%
dataset = pd.read_csv(r"..\datasets\Preprocessing.csv")
dataset
# Out:
#   Country   Age   Salary Purchased
# 0      US  43.0  71000.0        No
# 1      UK  28.0  48000.0       Yes
# 2   Japan  30.0  54000.0        No
# 3      UK  38.0  60000.0        No
# 4   Japan  40.0      NaN       Yes
# 5      US  34.0  58000.0       Yes
# 6      UK   NaN  53000.0        No
# 7      US  46.0  79000.0       Yes
# 8   Japan  50.0  83000.0        No
# 9      US  37.0  66000.0       Yes

# %% [markdown]
# # Determine the independent variables

# %%
# first three columns as matrix. independent variable
X = dataset.iloc[:,0:3].values
display(pd.DataFrame(X))
# Out:
#        0    1      2
# 0     US   43  71000
# 1     UK   28  48000
# 2  Japan   30  54000
# 3     UK   38  60000
# 4  Japan   40    NaN
# 5     US   34  58000
# 6     UK  NaN  53000
# 7     US   46  79000
# 8  Japan   50  83000
# 9     US   37  66000

# %% [markdown]
# # Determine the dependent variable

# %%
# last column as vector, dependent variable
y = dataset.iloc[:,-1].values
display(pd.DataFrame(y))
# Out:
#      0
# 0   No
# 1  Yes
# 2   No
# 3   No
# 4  Yes
# 5  Yes
# 6   No
# 7  Yes
# 8   No
# 9  Yes

# %% [markdown]
# # Handling missing data

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values = np.nan, strategy = 'median')
imputer = imputer.fit(X[:,1:3])
X[:, 1:3] = imputer.transform(X[:, 1:3])
display(pd.DataFrame(X))
# Out:
#        0   1      2
# 0     US  43  71000
# 1     UK  28  48000
# 2  Japan  30  54000
# 3     UK  38  60000
# 4  Japan  40  60000
# 5     US  34  58000
# 6     UK  38  53000
# 7     US  46  79000
# 8  Japan  50  83000
# 9     US  37  66000

# %% [markdown]
# # Encoding nominal data using label encoder

# %%
labelencoder_X = LabelEncoder()
X[:, 0] = labelencoder_X.fit_transform(X[:, 0])
display(pd.DataFrame(X))
# Out:
#    0   1      2
# 0  2  43  71000
# 1  1  28  48000
# 2  0  30  54000
# 3  1  38  60000
# 4  0  40  60000
# 5  2  34  58000
# 6  1  38  53000
# 7  2  46  79000
# 8  0  50  83000
# 9  2  37  66000

# %% [markdown]
# # Encoding categorial data with onehot encoding

# %%
onehotencoder = LabelBinarizer()
onehotencoder.fit(dataset['Country'])
transformed = onehotencoder.transform(dataset['Country'])
ohe_df = pd.DataFrame(transformed)
dataset = pd.concat([ohe_df, dataset], axis=1).drop(['Country'], axis=1)
dataset
# Out:
#    0  1  2   Age   Salary Purchased
# 0  0  0  1  43.0  71000.0        No
# 1  0  1  0  28.0  48000.0       Yes
# 2  1  0  0  30.0  54000.0        No
# 3  0  1  0  38.0  60000.0        No
# 4  1  0  0  40.0      NaN       Yes
# 5  0  0  1  34.0  58000.0       Yes
# 6  0  1  0   NaN  53000.0        No
# 7  0  0  1  46.0  79000.0       Yes
# 8  1  0  0  50.0  83000.0        No
# 9  0  0  1  37.0  66000.0       Yes

# %% [markdown]
# # Define matrix of independent variables

# %%
# first five columns as matrix. independent variable
X = dataset.iloc[:,0:5].values
display(pd.DataFrame(X))
# Out:
#      0    1    2     3        4
# 0  0.0  0.0  1.0  43.0  71000.0
# 1  0.0  1.0  0.0  28.0  48000.0
# 2  1.0  0.0  0.0  30.0  54000.0
# 3  0.0  1.0  0.0  38.0  60000.0
# 4  1.0  0.0  0.0  40.0      NaN
# 5  0.0  0.0  1.0  34.0  58000.0
# 6  0.0  1.0  0.0   NaN  53000.0
# 7  0.0  0.0  1.0  46.0  79000.0
# 8  1.0  0.0  0.0  50.0  83000.0
# 9  0.0  0.0  1.0  37.0  66000.0

# %% [markdown]
# # Define the vector of the dependent variable

# %%
# last column as vector, dependent variable
y = dataset.iloc[:,-1].values
display(pd.DataFrame(X))
display(pd.DataFrame(y))
# Out:
#      0    1    2     3        4
# 0  0.0  0.0  1.0  43.0  71000.0
# 1  0.0  1.0  0.0  28.0  48000.0
# 2  1.0  0.0  0.0  30.0  54000.0
# 3  0.0  1.0  0.0  38.0  60000.0
# 4  1.0  0.0  0.0  40.0      NaN
# 5  0.0  0.0  1.0  34.0  58000.0
# 6  0.0  1.0  0.0   NaN  53000.0
# 7  0.0  0.0  1.0  46.0  79000.0
# 8  1.0  0.0  0.0  50.0  83000.0
# 9  0.0  0.0  1.0  37.0  66000.0
#      0
# 0   No
# 1  Yes
# 2   No
# 3   No
# 4  Yes
# 5  Yes
# 6   No
# 7  Yes
# 8   No
# 9  Yes

# %% [markdown]
# # Handling missing data in the independent variable matrix

# %%
# Handling missing data of X
imputer = SimpleImputer(missing_values = np.nan, strategy = 'median')
imputer = imputer.fit(X[:,:])
X[:, :] = imputer.transform(X[:, :])
display(pd.DataFrame(X))
# Out:
#      0    1    2     3        4
# 0  0.0  0.0  1.0  43.0  71000.0
# 1  0.0  1.0  0.0  28.0  48000.0
# 2  1.0  0.0  0.0  30.0  54000.0
# 3  0.0  1.0  0.0  38.0  60000.0
# 4  1.0  0.0  0.0  40.0  60000.0
# 5  0.0  0.0  1.0  34.0  58000.0
# 6  0.0  1.0  0.0  38.0  53000.0
# 7  0.0  0.0  1.0  46.0  79000.0
# 8  1.0  0.0  0.0  50.0  83000.0
# 9  0.0  0.0  1.0  37.0  66000.0

# %% [markdown]
# # Handling missing data in the dependent variable vector

# %%
# Label encoding for y
labelencoder_y = LabelEncoder()
y = labelencoder_y.fit_transform(y)
display(pd.DataFrame(y))
# Out:
#    0
# 0  0
# 1  1
# 2  0
# 3  0
# 4  1
# 5  1
# 6  0
# 7  1
# 8  0
# 9  1

# %% [markdown]
# # Splitting the dataset into training and test set

# %%
#Splitting into training and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=0)
display(pd.DataFrame(X_train))
display(pd.DataFrame(y_train))
# Out:
#      0    1    2     3        4
# 0  1.0  0.0  0.0  40.0  60000.0
# 1  0.0  0.0  1.0  37.0  66000.0
# 2  0.0  1.0  0.0  28.0  48000.0
# 3  0.0  1.0  0.0  38.0  53000.0
# 4  0.0  0.0  1.0  46.0  79000.0
# 5  0.0  1.0  0.0  38.0  60000.0
# 6  0.0  0.0  1.0  43.0  71000.0
# 7  0.0  0.0  1.0  34.0  58000.0
#    0
# 0  1
# 1  1
# 2  1
# 3  0
# 4  1
# 5  0
# 6  0
# 7  1

# %% [markdown]
# # Feature scaling

# %% [markdown]
# ## MinMax Scaler

# %%
mmsc_X = MinMaxScaler()
X_train1 = mmsc_X.fit_transform(X_train)
display(pd.DataFrame(X_train1))
# Out:
#      0    1    2         3         4
# 0  1.0  0.0  0.0  0.666667  0.387097
# 1  0.0  0.0  1.0  0.500000  0.580645
# 2  0.0  1.0  0.0  0.000000  0.000000
# 3  0.0  1.0  0.0  0.555556  0.161290
# 4  0.0  0.0  1.0  1.000000  1.000000
# 5  0.0  1.0  0.0  0.555556  0.387097
# 6  0.0  0.0  1.0  0.833333  0.741935
# 7  0.0  0.0  1.0  0.333333  0.322581

# %% [markdown]
# ## Robust Scaler

# %%
rs_X = RobustScaler()
X_train2 = rs_X.fit_transform(X_train)
display(pd.DataFrame(X_train2))
# Out:
#      0    1    2         3         4
# 0  1.0  0.0 -0.5  0.444444  0.000000
# 1  0.0  0.0  0.5 -0.222222  0.571429
# 2  0.0  1.0 -0.5 -2.222222 -1.142857
# 3  0.0  1.0 -0.5  0.000000 -0.666667
# 4  0.0  0.0  0.5  1.777778  1.809524
# 5  0.0  1.0 -0.5  0.000000  0.000000
# 6  0.0  0.0  0.5  1.111111  1.047619
# 7  0.0  0.0  0.5 -0.888889 -0.190476

# %% [markdown]
# # Standard Scaler

# %%
sc_X = StandardScaler()
X_train3 = sc_X.fit_transform(X_train)
display(pd.DataFrame(X_train3))
# Out:
#           0         1    2        3         4
# 0  2.645751 -0.774597 -1.0  0.39036 -0.202352
# 1 -0.377964 -0.774597  1.0 -0.19518  0.445174
# 2 -0.377964  1.290994 -1.0 -1.95180 -1.497404
# 3 -0.377964  1.290994 -1.0  0.00000 -0.957799
# 4 -0.377964 -0.774597  1.0  1.56144  1.848148
# 5 -0.377964  1.290994 -1.0  0.00000 -0.202352
# 6 -0.377964 -0.774597  1.0  0.97590  0.984780
# 7 -0.377964 -0.774597  1.0 -0.78072 -0.418194

# %%
import plotly.figure_factory as ff

cols = ['Age', 'Salary']
#'Age MinMax', 'Salary MinMax', 'Age Robust', 'Salary Robust', 'Age Standard', 'Salary Standard']
df_plot = pd.DataFrame(columns = cols)

#df_plot['Age'] = X[:,3]
#df_plot['Salary'] = X[:,4]

x_Age = X[:,3]
x_Salary = X[:,4]

hist_data = [x_Age, x_Salary]

#df_plot

fig = ff.create_distplot(hist_data, cols, bin_size=.2)
fig.show()
# Out:
# <div>                            <div id="91200f4e-2bb1-45a3-9e6d-89487b741276" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("91200f4e-2bb1-45a3-9e6d-89487b741276")) {                    Plotly.newPlot(                        "91200f4e-2bb1-45a3-9e6d-89487b741276",                        [{"autobinx": false, "histnorm": "probability density", "legendgroup": "Age", "marker": {"color": "rgb(31, 119, 180)"}, "name": "Age", "opacity": 0.7, "type": "histogram", "x": [43.0, 28.0, 30.0, 38.0, 40.0, 34.0, 38.0, 46.0, 50.0, 37.0], "xaxis": "x", "xbins": {"end": 50.0, "size": 0.2, "start": 28.0}, "yaxis": "y"}, {"autobinx": false, "histnorm": "probability density", "legendgroup": "Salary", "marker": {"color": "rgb(255, 127, 14)"}, "name": "Salary", "opacity": 0.7, "type": "histogram", "x": [71000.0, 48000.0, 54000.0, 60000.0, 60000.0, 58000.0, 53000.0, 79000.0, 83000.0, 66000.0], "xaxis": "x", "xbins": {"end": 83000.0, "size": 0.2, "start": 48000.0}, "yaxis": "y"}, {"legendgroup": "Age", "marker": {"color": "rgb(31, 119, 180)"}, "mode": "lines", "name": "Age", "showlegend": false, "type": "scatter", "x": [28.0, 28.044, 28.088, 28.132, 28.176, 28.22, 28.264, 28.308, 28.352, 28.396, 28.44, 28.484, 28.528, 28.572, 28.616, 28.66, 28.704, 28.748, 28.792, 28.836, 28.88, 28.924, 28.968, 29.012, 29.056, 29.1, 29.144, 29.188, 29.232, 29.276, 29.32, 29.364, 29.408, 29.451999999999998, 29.496, 29.54, 29.584, 29.628, 29.672, 29.716, 29.76, 29.804, 29.848, 29.892, 29.936, 29.98, 30.024, 30.068, 30.112000000000002, 30.156, 30.2, 30.244, 30.288, 30.332, 30.376, 30.42, 30.464, 30.508, 30.552, 30.596, 30.64, 30.684, 30.728, 30.772, 30.816, 30.86, 30.904, 30.948, 30.992, 31.036, 31.08, 31.124, 31.168, 31.212, 31.256, 31.3, 31.344, 31.387999999999998, 31.432, 31.476, 31.52, 31.564, 31.608, 31.652, 31.696, 31.740000000000002, 31.784, 31.828, 31.872, 31.916, 31.96, 32.004, 32.048, 32.092, 32.136, 32.18, 32.224000000000004, 32.268, 32.312, 32.356, 32.4, 32.444, 32.488, 32.532, 32.576, 32.62, 32.664, 32.708, 32.752, 32.796, 32.84, 32.884, 32.928, 32.972, 33.016, 33.06, 33.104, 33.147999999999996, 33.192, 33.236, 33.28, 33.324, 33.368, 33.412, 33.456, 33.5, 33.544, 33.588, 33.632, 33.676, 33.72, 33.764, 33.808, 33.852000000000004, 33.896, 33.94, 33.984, 34.028, 34.072, 34.116, 34.16, 34.204, 34.248, 34.292, 34.336, 34.38, 34.424, 34.468, 34.512, 34.556, 34.6, 34.644, 34.688, 34.732, 34.775999999999996, 34.82, 34.864, 34.908, 34.952, 34.996, 35.04, 35.084, 35.128, 35.172, 35.216, 35.26, 35.304, 35.348, 35.392, 35.436, 35.480000000000004, 35.524, 35.568, 35.612, 35.656, 35.7, 35.744, 35.788, 35.832, 35.876, 35.92, 35.964, 36.007999999999996, 36.052, 36.096000000000004, 36.14, 36.184, 36.228, 36.272, 36.316, 36.36, 36.403999999999996, 36.448, 36.492000000000004, 36.536, 36.58, 36.624, 36.668, 36.712, 36.756, 36.8, 36.844, 36.888, 36.932, 36.976, 37.019999999999996, 37.064, 37.108000000000004, 37.152, 37.196, 37.24, 37.284, 37.328, 37.372, 37.416, 37.46, 37.504, 37.548, 37.592, 37.635999999999996, 37.68, 37.724000000000004, 37.768, 37.812, 37.856, 37.9, 37.944, 37.988, 38.032, 38.076, 38.12, 38.164, 38.208, 38.252, 38.296, 38.34, 38.384, 38.428, 38.472, 38.516, 38.56, 38.604, 38.647999999999996, 38.692, 38.736000000000004, 38.78, 38.824, 38.868, 38.912, 38.956, 39.0, 39.044, 39.088, 39.132, 39.176, 39.22, 39.263999999999996, 39.308, 39.352000000000004, 39.396, 39.44, 39.484, 39.528, 39.572, 39.616, 39.66, 39.704, 39.748, 39.792, 39.836, 39.88, 39.924, 39.968, 40.012, 40.056, 40.1, 40.144, 40.188, 40.232, 40.275999999999996, 40.32, 40.364000000000004, 40.408, 40.452, 40.496, 40.54, 40.584, 40.628, 40.672, 40.716, 40.76, 40.804, 40.848, 40.891999999999996, 40.936, 40.980000000000004, 41.024, 41.068, 41.112, 41.156, 41.2, 41.244,  ...
