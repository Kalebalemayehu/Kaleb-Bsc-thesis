# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_regression

from scipy.stats import probplot
from sklearn.preprocessing import MinMaxScaler
from numpy import arange
from sklearn.preprocessing import LabelBinarizer
from sklearn import metrics
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import r2_score

import warnings
warnings.simplefilter('ignore')

# %%
## Calulcating metrics
def calculate_metrics(df, crop_names, y_test, y_pred):
    mae = metrics.mean_absolute_error(y_test, y_pred)
    mse = metrics.mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
    mape = metrics.mean_absolute_percentage_error(y_test, y_pred)
    r2 = r2_score(y_test,y_pred)
    y_test_avg = pd.DataFrame(y_test).mean().iloc[0]
    y_pred_avg = pd.DataFrame(y_pred).mean().iloc[0]
    df.loc[crop_names] = [mae, mse, rmse,mape, r2, y_test_avg, y_pred_avg]

# %%
fao_data = pd.read_csv("datasets/latest0705.csv", index_col='Unnamed: 0')

fao_data
# Out:
#             Nutrient nitrogen N (total) - tonnes  \
# 1990-01-01                                   0.0
# 1990-01-01                                   0.0
# 1990-01-01                                   0.0
# 1990-01-01                                   0.0
# 1990-01-01                                   0.0
# ...                                          ...
# 2019-01-01                                   0.0
# 2020-01-01                             -106607.0
# 2020-01-01                                   0.0
# 2020-01-01                                   0.0
# 2020-01-01                                   0.0
#
#             Nutrient phosphate P2O5 (total) - tonnes  \
# 1990-01-01                                       0.0
# 1990-01-01                                       0.0
# 1990-01-01                                       0.0
# 1990-01-01                                       0.0
# 1990-01-01                                       0.0
# ...                                              ...
# 2019-01-01                                       0.0
# 2020-01-01                                  -55584.0
# 2020-01-01                                       0.0
# 2020-01-01                                       0.0
# 2020-01-01                                       0.0
#
#             Nutrient potash K2O (total) - tonnes                Item  \
# 1990-01-01                                   0.0              Apples
# 1990-01-01                                   0.0            Apricots
# 1990-01-01                                   0.0            Cherries
# 1990-01-01                                   0.0            Currants
# 1990-01-01                                   0.0        Gooseberries
# ...                                          ...                 ...
# 2019-01-01                                   0.0      Sunflower seed
# 2020-01-01                               26854.0           Hop cones
# 2020-01-01                                   0.0  Rape or colza seed
# 2020-01-01                                   0.0          Soya beans
# 2020-01-01                                   0.0      Sunflower seed
#
#             Yield(tonnes/ha)  Fung & Bact – Benzimidazoles  \
# 1990-01-01           26.3272                           0.0
# 1990-01-01            2.5781                           0.0
# 1990-01-01            5.0828                           0.0
# 1990-01-01            7.0383                           0.0
# 1990-01-01            6.8081                           0.0
# ...                      ...                           ...
# 2019-01-01           -0.8656                           0.0
# 2020-01-01            0.2323                         -15.0
# 2020-01-01            1.4064                           0.0
# 2020-01-01           -1.0056                           0.0
# 2020-01-01           -0.6208                           0.0
#
#             Fung & Bact – Diazines, morpholines  \
# 1990-01-01                                  0.0
# 1990-01-01                                  0.0
# 1990-01-01                                  0.0
# 1990-01-01                                  0.0
# 1990-01-01                                  0.0
# ...                                         ...
# 2019-01-01                                  0.0
# 2020-01-01                               -241.0
# 2020-01-01                                  0.0
# 2020-01-01                                  0.0
# 2020-01-01                                  0.0
#
#             Fung & Bact – Dithiocarbamates  Fung & Bact – Inorganics  \
# 1990-01-01                             0.0                       0.0
# 1990-01-01                             0.0                       0.0
# 1990-01-01                             0.0                       0.0
# 1990-01-01                             0.0                       0.0
# 1990-01-01                             0.0                       0.0
# ...                                    ...                       ...
# 2019-01-01                             0.0                       0.0
# 2020-01-01                           142.0                     140.0
# 2020-01-01                             0.0                       0.0
# 2020-01-01                             0.0                       0.0
# 2020-01-01                             0.0                       0.0
#
#             Fung & Bact – Other  ...  Rodenticides – Other-3  \
# 1990-01-01                  0.0  ...                     0.0
# 1990-01-01                  0.0  ...                     0.0
# 1990-01-01                  0.0  ...                     0.0
# 1990-01-01                  0.0  ...                     0.0
# 1990-01-01                  0.0  ...                     0.0
# ...                         ...  ...                     ...
# 2019-01-01                  0.0  ...                     5.0
# 2020-01-01               -773.0  ...                     0.0
# 2020-01-01                  0.0  ...                     0.0
# 2020-01-01                  0.0  ...                     0.0
# 2020-01-01                  0.0  ...                     6.0
#
#             Herbicides – Bipiridils-1  Herbicides – Bipiridils-2  \
# 1990-01-01                        0.0                        0.0
# 1990-01-01                        0.0                        0.0
# 1990-01-01                        0.0                        0.0
# 1990-01-01                        0.0                        0.0
# 1990-01-01                        0.0                        0.0
# ...                               ...                        ...
# 2019-01-01                        0.0                        0.0
# 2020-01-01                        0.0                        0.0
# 2020-01-01                      -84.0                        0.0
# 2020-01-01                        0.0                      -84.0
# 2020-01-01                        0.0                        0.0
#
#             Herbicides – Bipiridils-3  Herbicides – Sulfonyl ureas-1  \
# 1990-01-01                        0.0                            0.0
# 1990-01-01                        0.0                            0.0
# 1990-01-01                        0.0                            0.0
# 1990-01-01                        0.0                            0.0
# 1990-01-01                        0.0                            0.0
# ...                               ...                            ...
# 2019-01-01                      -81.0                            0.0
# 2020-01-01                        0.0                            0.0
# 2020-01-01                        0.0                            4.0
# 2020-01-01                        0.0                            0.0
# 2020-01-01                      -84.0                            0.0
#
#             Herbicides – Sulfonyl ureas-2  Herbicides – Sulfonyl ureas-3  \
# 1990-01-01                            0.0                            0.0
# 1990-01-01                            0.0                            0.0
# 1990-01-01                            0.0                            0.0
# 1990-01-01                            0.0                            0.0
# 1990-01-01                            0.0                            0.0
# ...                                   ...                            ...
# 2019-01-01                            0.0                           31.0
# 2020-01-01                            0.0                            0.0
# 2020-01-01                            0.0                            0.0
# 2020-01-01                            4.0                            0.0
# 2020-01-01                            0.0                            4.0
#
#             Rodenticides – Anti-coagulants-1  \
# 1990-01-01                              5.00
# 1990-01-01                              5.00
# 1990-01-01                              5.00
# 1990-01-01                              5.00
# 1990-01-01                              5.00
# ...                                      ...
# 2019-01-01                              0.41
# 2020-01-01                              0.41
# 2020-01-01                              0.10
# 2020-01-01                              0.10
# 2020-01-01                              0.10
#
#             Rodenticides – Anti-coagulants-2  Rodenticides – Anti-coagulants-3
# 1990-01-01                              5.00                              5.00
# 1990-01-01                              5.00                              5.00
# 1990-01-01                              5.00                              5.00
# 1990-01-01                              5.00                              5.00
# 1990-01-01                              5.00                              5.00
# ...                                      ...                               ...
# 2019-01-01                              0.41                              0.41
# 2020-01-01                              0.41                              0.41
# 2020-01-01                              0.41                              0.41
# 2020-01-01                              0.10                              0.41
# 2020-01-01                              0.10                              0.10
#
# [1574 rows x 115 columns]

# %%
fao_data['Category'].value_counts()
# Out:
# Vegetables and Legumes    670
# Fruits and Nuts           450
# Industrial_crops          237
# Cereals                   217
# Name: Category, dtype: int64

# %%
cat_names = fao_data['Category'].unique()
cat_names
# Out:
# array(['Fruits and Nuts', 'Vegetables and Legumes', 'Cereals',
#        'Industrial_crops'], dtype=object)

# %%
quality_metrics = ['GBR_MAE', 'GBR_MSE', 'GBR_RMSE', 'GBR_MAPE', 'GBR_r2_score', 'y_test_avg', 'y_pred_avg']
error_df = pd.DataFrame(columns = quality_metrics, index = cat_names)
#display(error_df)

# %%
scaler = MinMaxScaler()
for cat in cat_names:
    crop_df = fao_data[fao_data['Category'] == cat]
    encoded_df = pd.get_dummies(crop_df[["Crop_season"]], prefix='', prefix_sep='')

    y = crop_df[['Yield(tonnes/ha)']]
    x = crop_df.drop(['Yield(tonnes/ha)', "Item", "Category", "Crop_season"], axis=1)
    x = pd.concat([x, encoded_df], axis=1)
    

    mean = x.mean()
    std = x.std()
    lower_bound = mean - 2 * std
    upper_bound = mean + 2 * std
    x = x.clip(lower_bound, upper_bound, axis=1)

    x = scaler.fit_transform(x)
  
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, shuffle=False)
    regressor = GradientBoostingRegressor(n_estimators=1000, learning_rate= 1)
    regressor.fit(x_train, y_train)


    #prediction of new value
    y_pred = regressor.predict(x_test)

    calculate_metrics(error_df, cat , y_test, y_pred)
    residuals = y_test['Yield(tonnes/ha)'] - regressor.predict(x_test)
    probplot(residuals, dist="norm", plot=plt)

# %%
error_df
# Out:
#                           GBR_MAE     GBR_MSE   GBR_RMSE  GBR_MAPE  \
# Fruits and Nuts          4.602076   46.874262   6.846478  0.636367
# Vegetables and Legumes  16.325881  530.897127  23.041205  1.251889
# Cereals                  0.686717    1.115581   1.056211  0.757481
# Industrial_crops         0.700086    0.961627   0.980626  1.598042
#
#                        GBR_r2_score y_test_avg y_pred_avg
# Fruits and Nuts            0.074341    9.62286   9.101742
# Vegetables and Legumes     0.851072  45.745672   39.78182
# Cereals                    0.808875   0.038645   0.372625
# Industrial_crops           0.446291   0.030727  -0.115684
