# %%
import pandas as pd

# %%
df_soil = pd.read_csv('smu_ptrdb.csv')
df_soil
# Out:
#           smu  erodi erodi_c  erodi_p  txerod txerod_c  txerod_p  crusting  \
# 0           1      0       v    100.0       0        v     100.0         3
# 1           2      0       v    100.0       0        v     100.0         3
# 2           3      0       v    100.0       0        v     100.0         3
# 3           4      0       v    100.0       0        v     100.0         3
# 4           5      0       v    100.0       0        v     100.0         3
# ...       ...    ...     ...      ...     ...      ...       ...       ...
# 3851  4420573      4       v    100.0       4        v     100.0         5
# 3852  4420574      3       v    100.0       3        v     100.0         4
# 3853  4420575      4       v     70.0       3        v     100.0         3
# 3854  4420576      1       v     50.0       1        v      50.0         1
# 3855  4420577      3       v     70.0       3        v      70.0         2
#
# ...

# %%
df_prod = pd.read_xml('sqi_fig4_crop1.tif.aux.xml')
# Out:
# Traceback (most recent call last):
#
#   File "/Users/kalebalemayehu/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "/var/folders/l4/pbw5dk1139gdk7nt6gdt2yp40000gn/T/ipykernel_27031/2600551299.py", line 1, in <module>
#     df_prod = pd.read_xml('sqi_fig4_crop1.tif.aux.xml')
#
#   File "/Users/kalebalemayehu/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py", line 317, in wrapper
#     return func(*args, **kwargs)
#
#   File "/Users/kalebalemayehu/opt/anaconda3/lib/python3.9/site-packages/pandas/io/xml.py", line 1088, in read_xml
#     return _parse(
#
#   File "/Users/kalebalemayehu/opt/anaconda3/lib/python3.9/site-packages/pandas/io/xml.py", line 827, in _parse
#     data_dicts = p.parse_data()
#
#   File "/Users/kalebalemayehu/opt/anaconda3/lib/python3.9/site-packages/pandas/io/xml.py", line 551, in parse_data
# ...
