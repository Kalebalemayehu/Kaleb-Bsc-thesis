# %%
import pandas as pd
from sklearn.preprocessing import LabelBinarizer
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fao_data = pd.read_csv('master_data.csv')
del fao_data['Unnamed: 0']
fao_data
# Out:
#      Year  Nutrient nitrogen N (total) - tonnes  \
# 0    2002                               1787833
# 1    2002                               1787833
# 2    2002                               1787833
# 3    2002                               1787833
# 4    2002                               1787833
# ..    ...                                   ...
# 817  2020                               1265477
# 818  2020                               1265477
# 819  2020                               1265477
# 820  2020                               1265477
# 821  2020                               1265477
#
#      Nutrient phosphate P2O5 (total) - tonnes  \
# 0                                      327387
# 1                                      327387
# 2                                      327387
# 3                                      327387
# 4                                      327387
# ..                                        ...
# 817                                    192182
# ...

# %%
fao_data['Item'].value_counts()
# Out:
# Rape or colza seed                                              19
# Onions and shallots, dry (excluding dehydrated)                 19
# Wheat                                                           19
# Triticale                                                       19
# Tomatoes                                                        19
# Sunflower seed                                                  19
# Sugar beet                                                      19
# Strawberries                                                    19
# Spinach                                                         19
# Rye                                                             19
# Asparagus                                                       19
# Potatoes                                                        19
# Plums and sloes                                                 19
# Peas, dry                                                       19
# ...

# %%
pivot_table = fao_data.pivot_table(columns='Item', values='Yield(hg/ha)')
sns.heatmap(pivot_table, cmap='YlGnBu')
# Out:
# <AxesSubplot:xlabel='Item'>
